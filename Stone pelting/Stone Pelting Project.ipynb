# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
import glob
import pandas as pd
import os

# %%
os.listdir("/content/drive/MyDrive/No Stone pelting/")
# Out:
# ['images.jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg',
#  'images (2).jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg',
#  'images (1).jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg',
#  'images (4).jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg',
#  'images (3).jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg',
#  'images (5).jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg',
#  'download.jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg',
#  'download (3).jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg',
#  'download (2).jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg',
# ...

# %%
for i in glob.glob("/content/drive/MyDrive/No Stone pelting/"+"*.jpeg"):
  os.rename(i,i+"_nostonepelting"+'.jpeg')

# %%
for j in glob.glob("/content/drive/MyDrive/Stone pelting/"+"*.jpg"):
  os.rename(j,j+"_stonepelting"+'.jpeg')

# %%
for i in glob.glob("/content/drive/MyDrive/No Stone pelting/"+"*.jpeg"):
  print(i)
# Out:
# /content/drive/MyDrive/No Stone pelting/images.jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg
# /content/drive/MyDrive/No Stone pelting/images (2).jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg
# /content/drive/MyDrive/No Stone pelting/images (1).jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg
# /content/drive/MyDrive/No Stone pelting/images (4).jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg
# /content/drive/MyDrive/No Stone pelting/images (3).jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg
# /content/drive/MyDrive/No Stone pelting/images (5).jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg
# ...

# %%
for j in glob.glob("/content/drive/MyDrive/Stone pelting/"+"*.jpeg"):
  print(j)
# Out:
# /content/drive/MyDrive/Stone pelting/download.jpg_stonepelting.jpeg
# /content/drive/MyDrive/Stone pelting/download (1).jpg_stonepelting.jpeg
# /content/drive/MyDrive/Stone pelting/download (2).jpg_stonepelting.jpeg
# /content/drive/MyDrive/Stone pelting/download (3).jpg_stonepelting.jpeg
# /content/drive/MyDrive/Stone pelting/download (4).jpg_stonepelting.jpeg
# /content/drive/MyDrive/Stone pelting/download (5).jpg_stonepelting.jpeg
# /content/drive/MyDrive/Stone pelting/download (6).jpg_stonepelting.jpeg
# /content/drive/MyDrive/Stone pelting/images.jpg_stonepelting.jpeg
# /content/drive/MyDrive/Stone pelting/images (1).jpg_stonepelting.jpeg
# /content/drive/MyDrive/Stone pelting/images (2).jpg_stonepelting.jpeg
# /content/drive/MyDrive/Stone pelting/images (3).jpg_stonepelting.jpeg
# /content/drive/MyDrive/Stone pelting/images (4).jpg_stonepelting.jpeg
# /content/drive/MyDrive/Stone pelting/images (5).jpg_stonepelting.jpeg
# ...

# %%
file_name_no=[]
label_no=[]
for i in glob.glob("/content/drive/MyDrive/No Stone pelting/"+"*.jpeg"):
  file_name_no.append(i)
  extract_label=i.split('/')[-1]
  label_no.append(extract_label.split("_")[-1][:-5])

# %%
file_name_no
# Out:
# ['/content/drive/MyDrive/No Stone pelting/images.jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg',
#  '/content/drive/MyDrive/No Stone pelting/images (2).jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg',
#  '/content/drive/MyDrive/No Stone pelting/images (1).jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg',
#  '/content/drive/MyDrive/No Stone pelting/images (4).jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg',
#  '/content/drive/MyDrive/No Stone pelting/images (3).jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg',
#  '/content/drive/MyDrive/No Stone pelting/images (5).jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg',
# ...

# %%
label_no
# Out:
# ['nostonepelting',
#  'nostonepelting',
#  'nostonepelting',
#  'nostonepelting',
#  'nostonepelting',
#  'nostonepelting',
#  'nostonepelting',
#  'nostonepelting',
#  'nostonepelting',
#  'nostonepelting',
#  'nostonepelting']

# %%
no_stone_pelting = pd.DataFrame({'File_Name':file_name_no,"Labels":label_no})
no_stone_pelting
# Out:
#                                             File_Name          Labels
# 0   /content/drive/MyDrive/No Stone pelting/images...  nostonepelting
# 1   /content/drive/MyDrive/No Stone pelting/images...  nostonepelting
# 2   /content/drive/MyDrive/No Stone pelting/images...  nostonepelting
# 3   /content/drive/MyDrive/No Stone pelting/images...  nostonepelting
# 4   /content/drive/MyDrive/No Stone pelting/images...  nostonepelting
# 5   /content/drive/MyDrive/No Stone pelting/images...  nostonepelting
# 6   /content/drive/MyDrive/No Stone pelting/downlo...  nostonepelting
# 7   /content/drive/MyDrive/No Stone pelting/downlo...  nostonepelting
# 8   /content/drive/MyDrive/No Stone pelting/downlo...  nostonepelting
# 9   /content/drive/MyDrive/No Stone pelting/downlo...  nostonepelting
# 10  /content/drive/MyDrive/No Stone pelting/downlo...  nostonepelting

# %%
file_name=[]
label=[]
for i in glob.glob("/content/drive/MyDrive/Stone pelting/"+"*.jpeg"):
  file_name.append(i)
  extract=i.split("/")[-1]
  label.append(extract.split("_")[-1][:-5])

# %%
stone_pelting = pd.DataFrame({"File_Name":file_name,"Labels":label})
stone_pelting
# Out:
#                                             File_Name        Labels
# 0   /content/drive/MyDrive/Stone pelting/download....  stonepelting
# 1   /content/drive/MyDrive/Stone pelting/download ...  stonepelting
# 2   /content/drive/MyDrive/Stone pelting/download ...  stonepelting
# 3   /content/drive/MyDrive/Stone pelting/download ...  stonepelting
# 4   /content/drive/MyDrive/Stone pelting/download ...  stonepelting
# 5   /content/drive/MyDrive/Stone pelting/download ...  stonepelting
# 6   /content/drive/MyDrive/Stone pelting/download ...  stonepelting
# 7   /content/drive/MyDrive/Stone pelting/images.jp...  stonepelting
# 8   /content/drive/MyDrive/Stone pelting/images (1...  stonepelting
# 9   /content/drive/MyDrive/Stone pelting/images (2...  stonepelting
# 10  /content/drive/MyDrive/Stone pelting/images (3...  stonepelting
# 11  /content/drive/MyDrive/Stone pelting/images (4...  stonepelting
# 12  /content/drive/MyDrive/Stone pelting/images (5...  stonepelting
# ...

# %%
master_data = pd.concat([no_stone_pelting,stone_pelting],axis=0)
master_data
# Out:
#                                             File_Name          Labels
# 0   /content/drive/MyDrive/No Stone pelting/images...  nostonepelting
# 1   /content/drive/MyDrive/No Stone pelting/images...  nostonepelting
# 2   /content/drive/MyDrive/No Stone pelting/images...  nostonepelting
# 3   /content/drive/MyDrive/No Stone pelting/images...  nostonepelting
# 4   /content/drive/MyDrive/No Stone pelting/images...  nostonepelting
# 5   /content/drive/MyDrive/No Stone pelting/images...  nostonepelting
# 6   /content/drive/MyDrive/No Stone pelting/downlo...  nostonepelting
# 7   /content/drive/MyDrive/No Stone pelting/downlo...  nostonepelting
# 8   /content/drive/MyDrive/No Stone pelting/downlo...  nostonepelting
# 9   /content/drive/MyDrive/No Stone pelting/downlo...  nostonepelting
# 10  /content/drive/MyDrive/No Stone pelting/downlo...  nostonepelting
# 0   /content/drive/MyDrive/Stone pelting/download....    stonepelting
# ...

# %%
master_data=master_data.sample(frac=1)
master_data
# Out:
#                                             File_Name          Labels
# 4   /content/drive/MyDrive/Stone pelting/download ...    stonepelting
# 5   /content/drive/MyDrive/Stone pelting/download ...    stonepelting
# 26  /content/drive/MyDrive/Stone pelting/images (1...    stonepelting
# 29  /content/drive/MyDrive/Stone pelting/images (2...    stonepelting
# 6   /content/drive/MyDrive/Stone pelting/download ...    stonepelting
# 24  /content/drive/MyDrive/Stone pelting/images (1...    stonepelting
# 2   /content/drive/MyDrive/Stone pelting/download ...    stonepelting
# 8   /content/drive/MyDrive/Stone pelting/images (1...    stonepelting
# 38  /content/drive/MyDrive/Stone pelting/images (3...    stonepelting
# 35  /content/drive/MyDrive/Stone pelting/images (2...    stonepelting
# 9   /content/drive/MyDrive/No Stone pelting/downlo...  nostonepelting
# 3   /content/drive/MyDrive/No Stone pelting/images...  nostonepelting
# ...

# %%
master_data.reset_index(inplace=True)
master_data.drop(['index'],axis=1,inplace=True)
master_data
# Out:
#                                             File_Name          Labels
# 0   /content/drive/MyDrive/Stone pelting/download ...    stonepelting
# 1   /content/drive/MyDrive/Stone pelting/download ...    stonepelting
# 2   /content/drive/MyDrive/Stone pelting/images (1...    stonepelting
# 3   /content/drive/MyDrive/Stone pelting/images (2...    stonepelting
# 4   /content/drive/MyDrive/Stone pelting/download ...    stonepelting
# 5   /content/drive/MyDrive/Stone pelting/images (1...    stonepelting
# 6   /content/drive/MyDrive/Stone pelting/download ...    stonepelting
# 7   /content/drive/MyDrive/Stone pelting/images (1...    stonepelting
# 8   /content/drive/MyDrive/Stone pelting/images (3...    stonepelting
# 9   /content/drive/MyDrive/Stone pelting/images (2...    stonepelting
# 10  /content/drive/MyDrive/No Stone pelting/downlo...  nostonepelting
# 11  /content/drive/MyDrive/No Stone pelting/images...  nostonepelting
# ...

# %% [markdown]
# ## Train ,Test, Validation

# %%
x = master_data.values
len(x)
# Out:
# 50

# %%
cols=master_data.columns.values
cols
# Out:
# array(['File_Name', 'Labels'], dtype=object)

# %%
df_train = x[:int(len(x)*.90)]

# %%
df_test = x[int(len(x)*.90):]

# %%
df_train
# Out:
# array([['/content/drive/MyDrive/Stone pelting/download (4).jpg_stonepelting.jpeg',
#         'stonepelting'],
#        ['/content/drive/MyDrive/Stone pelting/download (5).jpg_stonepelting.jpeg',
#         'stonepelting'],
#        ['/content/drive/MyDrive/Stone pelting/images (19).jpg_stonepelting.jpeg',
#         'stonepelting'],
#        ['/content/drive/MyDrive/Stone pelting/images (22).jpg_stonepelting.jpeg',
#         'stonepelting'],
#        ['/content/drive/MyDrive/Stone pelting/download (6).jpg_stonepelting.jpeg',
#         'stonepelting'],
#        ['/content/drive/MyDrive/Stone pelting/images (17).jpg_stonepelting.jpeg',
#         'stonepelting'],
#        ['/content/drive/MyDrive/Stone pelting/download (2).jpg_stonepelting.jpeg',
#         'stonepelting'],
#        ['/content/drive/MyDrive/Stone pelting/images (1).jpg_stonepelting.jpeg',
#         'stonepelting'],
#        ['/content/drive/MyDrive/Stone pelting/images (31).jpg_stonepelting.jpeg',
# ...

# %%
df_train = pd.DataFrame(df_train,columns=cols)

# %%
df_test = pd.DataFrame(df_test,columns=cols)

# %%
df_train
# Out:
#                                             File_Name          Labels
# 0   /content/drive/MyDrive/Stone pelting/download ...    stonepelting
# 1   /content/drive/MyDrive/Stone pelting/download ...    stonepelting
# 2   /content/drive/MyDrive/Stone pelting/images (1...    stonepelting
# 3   /content/drive/MyDrive/Stone pelting/images (2...    stonepelting
# 4   /content/drive/MyDrive/Stone pelting/download ...    stonepelting
# 5   /content/drive/MyDrive/Stone pelting/images (1...    stonepelting
# 6   /content/drive/MyDrive/Stone pelting/download ...    stonepelting
# 7   /content/drive/MyDrive/Stone pelting/images (1...    stonepelting
# 8   /content/drive/MyDrive/Stone pelting/images (3...    stonepelting
# 9   /content/drive/MyDrive/Stone pelting/images (2...    stonepelting
# 10  /content/drive/MyDrive/No Stone pelting/downlo...  nostonepelting
# 11  /content/drive/MyDrive/No Stone pelting/images...  nostonepelting
# ...

# %%
df_train['Labels'].value_counts()
# Out:
# stonepelting      35
# nostonepelting    10
# Name: Labels, dtype: int64

# %%
df_train.to_csv("Training_csv.csv",index=False)

# %%
df_test
# Out:
#                                            File_Name          Labels
# 0  /content/drive/MyDrive/No Stone pelting/images...  nostonepelting
# 1  /content/drive/MyDrive/Stone pelting/download....    stonepelting
# 2  /content/drive/MyDrive/Stone pelting/images (5...    stonepelting
# 3  /content/drive/MyDrive/Stone pelting/images (3...    stonepelting
# 4  /content/drive/MyDrive/Stone pelting/download ...    stonepelting

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import image
from keras.callbacks import ModelCheckpoint,EarlyStopping
import matplotlib.pyplot as plt

# %%
train_generator = ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    width_shift_range=0.2,
    height_shift_range=0.2,
    validation_split=0.2
)

# %%
test_generator = ImageDataGenerator(
    rescale=1./255
)

# %%
df_train.head()
# Out:
#                                            File_Name        Labels
# 0  /content/drive/MyDrive/Stone pelting/download ...  stonepelting
# 1  /content/drive/MyDrive/Stone pelting/download ...  stonepelting
# 2  /content/drive/MyDrive/Stone pelting/images (1...  stonepelting
# 3  /content/drive/MyDrive/Stone pelting/images (2...  stonepelting
# 4  /content/drive/MyDrive/Stone pelting/download ...  stonepelting

# %%
df_train['Labels'].unique()
# Out:
# array(['stonepelting', 'nostonepelting'], dtype=object)

# %%
df_train['Labels'] = df_train['Labels'].replace({"nostonepelting":0,"stonepelting":1})

# %%
df_train.head()
# Out:
#                                            File_Name  Labels
# 0  /content/drive/MyDrive/Stone pelting/download ...       1
# 1  /content/drive/MyDrive/Stone pelting/download ...       1
# 2  /content/drive/MyDrive/Stone pelting/images (1...       1
# 3  /content/drive/MyDrive/Stone pelting/images (2...       1
# 4  /content/drive/MyDrive/Stone pelting/download ...       1

# %%
train_images = train_generator.flow_from_dataframe(
    dataframe=df_train,
    x_col='File_Name',
    y_col='Labels',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='raw',
    batch_size=4,
    shuffle=True,
    subset='training'
)
# Out:
# Found 36 validated image filenames.

# %%
val_images = train_generator.flow_from_dataframe(
    dataframe=df_train,
    x_col='File_Name',
    y_col='Labels',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='raw',
    batch_size=4,
    shuffle=True,
    subset='validation'
)
# Out:
# Found 9 validated image filenames.

# %%
test_images = test_generator.flow_from_dataframe(
    dataframe=df_test,
    x_col='File_Name',
    y_col='Labels',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='raw',
    batch_size=4,
    shuffle=True,
)
# Out:
# Found 5 validated image filenames.

# %%
# import shutil

# %%
# for i in df_train['File_Name']:
#   print(i)

# %%
# for i in df_train['File_Name']:
#   shutil.copy(i,'/content/Training_images/')

# %%
pre_trained = InceptionV3(weights='imagenet', include_top=False, input_shape=(228,228,3), pooling='avg')

# %%
for layer in pre_trained.layers:
    layer.trainable = False

# %%
x = pre_trained.output
x = Dropout(0.25)(x)
x = Dense(4096, activation='relu')(x)
x = Dropout(0.25)(x)
x = Dense(2048, activation='relu')(x)
x = Dropout(0.25)(x)
predictions = Dense(2, activation='sigmoid')(x)
model = Model(inputs = pre_trained.input, outputs = predictions)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 228, 228, 3  0           []
#                                 )]
#
#  conv2d_94 (Conv2D)             (None, 113, 113, 32  864         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_94 (BatchN  (None, 113, 113, 32  96         ['conv2d_94[0][0]']
#  ormalization)                  )
#
#  activation_94 (Activation)     (None, 113, 113, 32  0           ['batch_normalization_94[0][0]']
#                                 )
#
#  conv2d_95 (Conv2D)             (None, 111, 111, 32  9216        ['activation_94[0][0]']
#                                 )
#
#  batch_normalization_95 (BatchN  (None, 111, 111, 32  96         ['conv2d_95[0][0]']
#  ormalization)                  )
#
# ...

# %%
model.compile(optimizer='adam',loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
checkpoint = ModelCheckpoint('my_model.h5',verbose=1,save_best_only=True)

# %%
STEP_SIZE_TRAIN = train_images.n // train_images.batch_size
STEP_SIZE_VALID = val_images.n // val_images.batch_size

# %%
history = model.fit_generator(train_images,
                    steps_per_epoch = STEP_SIZE_TRAIN,
                    validation_data = val_images,
                    validation_steps = STEP_SIZE_VALID,
                    callbacks=[checkpoint],
                    epochs = 10)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 9/9 [==============================] - ETA: 0s - loss: 15.2302 - accuracy: 0.5556
# Epoch 1: val_loss improved from inf to 0.01817, saving model to my_model.h5
# 9/9 [==============================] - 25s 1s/step - loss: 15.2302 - accuracy: 0.5556 - val_loss: 0.0182 - val_accuracy: 1.0000
# Epoch 2/10
# 9/9 [==============================] - ETA: 0s - loss: 2.2918 - accuracy: 0.6111
# ...

# %%
from imutils import paths
from numpy import random
import imutils
import cv2

# %%
Nostone_pelting = list(paths.list_images('/content/drive/MyDrive/No Stone pelting/'))

# %%
imagepaths = Nostone_pelting

# %%
Nostone_pelting
# Out:
# ['/content/drive/MyDrive/No Stone pelting/images.jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg',
#  '/content/drive/MyDrive/No Stone pelting/images (2).jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg',
#  '/content/drive/MyDrive/No Stone pelting/images (1).jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg',
#  '/content/drive/MyDrive/No Stone pelting/images (4).jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg',
#  '/content/drive/MyDrive/No Stone pelting/images (3).jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg',
#  '/content/drive/MyDrive/No Stone pelting/images (5).jpg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg_nostonepelting.jpeg',
# ...

# %%
random.shuffle(imagepaths)

# %%
classes=['stonepelting','nostonepelting']

# %%
classes[0]
# Out:
# 'stonepelting'

# %%
import numpy as np

# %%
for (i,imagepath) in enumerate(imagepaths):
  image = cv2.imread(imagepath)
  output = image.copy()
  image = cv2.resize(image,(228,228))
  image = image.astype('float32')/255.0

  pred = model.predict(np.expand_dims(image,axis=0))[0]
  idx = np.argmax(pred)

  label = classes[idx]

  text = label if label =="StonePelting" else "NoStonePelting"
  output = imutils.resize(output,width=500)
  cv2.putText(output,text,(10,30),cv2.FONT_HERSHEY_TRIPLEX,1,(0,0,255),thickness=2)
  filename="{}.png".format(i)
  path='noStonepredicted_images01'
  if not os.path.isdir(path):

    os.makedirs(path)
  p=os.path.sep.join([path,filename])
  cv2.imwrite(p,output)

# %%
x = pre_trained.output
x = Dropout(0.25)(x)
x = Dense(4096, activation='relu')(x)
x = Dropout(0.25)(x)
x = Dense(2048, activation='relu')(x)
x = Dropout(0.25)(x)
predictions = Dense(2, activation='sigmoid')(x)
model = Model(inputs = pre_trained.input, outputs = predictions)

# %%
model.compile(optimizer='adam',loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
model.load_weights('/content/my_model.h5')

# %%
history = model.fit(
    train_images,
    validation_data=val_images,
    epochs=10,
    callbacks=[checkpoint]
)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 9/9 [==============================] - ETA: 0s - loss: 1.0380 - accuracy: 0.8889
# Epoch 1: val_loss did not improve from 0.00000
# 9/9 [==============================] - 6s 268ms/step - loss: 1.0380 - accuracy: 0.8889 - val_loss: 7.5697e-05 - val_accuracy: 1.0000
# Epoch 2/10
# 9/9 [==============================] - ETA: 0s - loss: 0.1631 - accuracy: 0.9722
# Epoch 2: val_loss did not improve from 0.00000
# 9/9 [==============================] - 1s 86ms/step - loss: 0.1631 - accuracy: 0.9722 - val_loss: 5.2916e-04 - val_accuracy: 1.0000
# Epoch 3/10
# 9/9 [==============================] - ETA: 0s - loss: 0.4039 - accuracy: 0.9167
# ...

# %%
stone_pelting = list(paths.list_images('/content/drive/MyDrive/Stone pelting/'))

# %%
No_imagepaths = stone_pelting

# %%
stone_pelting
# Out:
# ['/content/drive/MyDrive/Stone pelting/download.jpg_stonepelting.jpeg',
#  '/content/drive/MyDrive/Stone pelting/download (1).jpg_stonepelting.jpeg',
#  '/content/drive/MyDrive/Stone pelting/download (2).jpg_stonepelting.jpeg',
#  '/content/drive/MyDrive/Stone pelting/download (3).jpg_stonepelting.jpeg',
#  '/content/drive/MyDrive/Stone pelting/download (4).jpg_stonepelting.jpeg',
#  '/content/drive/MyDrive/Stone pelting/download (5).jpg_stonepelting.jpeg',
#  '/content/drive/MyDrive/Stone pelting/download (6).jpg_stonepelting.jpeg',
#  '/content/drive/MyDrive/Stone pelting/images.jpg_stonepelting.jpeg',
#  '/content/drive/MyDrive/Stone pelting/images (1).jpg_stonepelting.jpeg',
#  '/content/drive/MyDrive/Stone pelting/images (2).jpg_stonepelting.jpeg',
#  '/content/drive/MyDrive/Stone pelting/images (3).jpg_stonepelting.jpeg',
#  '/content/drive/MyDrive/Stone pelting/images (4).jpg_stonepelting.jpeg',
#  '/content/drive/MyDrive/Stone pelting/images (5).jpg_stonepelting.jpeg',
# ...

# %%
random.shuffle(imagepaths)
classes=['nostonepelting','stonepelting']

# %%
for (i,No_imagepaths) in enumerate(No_imagepaths):
  image = cv2.imread(No_imagepaths)
  output = image.copy()
  image = cv2.resize(image,(228,228))
  image = image.astype('float32')/255.0

  pred = model.predict(np.expand_dims(image,axis=0))[0]
  idx = np.argmax(pred)

  label = classes[idx]

  text = label if label =="NoStonePelting" else "StonePelting"
  output = imutils.resize(output,width=500)
  cv2.putText(output,text,(10,30),cv2.FONT_HERSHEY_TRIPLEX,1,(0,0,255),thickness=2)
  filename="{}.png".format(i)
  path='Stonepredicted_images01'
  if not os.path.isdir(path):

    os.makedirs(path)
  p=os.path.sep.join([path,filename])
  cv2.imwrite(p,output)
